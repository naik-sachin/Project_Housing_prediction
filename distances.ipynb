# %%
import pandas as pd

# %%
df = pd.read_csv('data/kc_housing_distances.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  2014-10-13  221900.0         3       1.00         1180
# 1  6414100192  2014-09-12  538000.0         3       2.25         2570
# 2  5631500400  2015-02-25  180000.0         2       1.00          770
# 3  2487200875  2014-09-12  604000.0         4       3.00         1960
# 4  1954400510  2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...      lat     long  sqft_living15  \
# 0      5650     1.0         0.0   0.0  ...  47.5112 -122.257           1340
# 1      7242     2.0         0.0   0.0  ...  47.7210 -122.319           1690
# 2     10000     1.0         0.0   0.0  ...  47.7379 -122.233           2720
# 3      5000     1.0         0.0   0.0  ...  47.5208 -122.393           1360
# 4      8080     1.0         0.0   0.0  ...  47.6168 -122.045           1800
#
#    sqft_lot15  distance_to_airport  distance_to_seahawks_stadium  \
# ...

# %%
df['lat'][0]
# Out:
# numpy.float64

# %%
import json
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# %%
keys = get_keys("/Users/Laurel/DS/.secret/google_api.json")

api_key = keys['api_key']

# %%
type(api_key)
# Out:
# str

# %%
import requests

for i in range (0,len(df['long'])): 
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?key="+api_key+"&location=" + str(df['lat'][i]) + "," + str(df['long'][i]) + "&rankby=distance&type=train_station"
    response = requests.get(url)
    print(response.text[:1000])
# Out:
# {
#    "error_message" : "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#    "html_attributions" : [],
#    "results" : [],
#    "status" : "REQUEST_DENIED"
# }
#
# {
#    "error_message" : "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#    "html_attributions" : [],
#    "results" : [],
#    "status" : "REQUEST_DENIED"
# }
#
# {
#    "error_message" : "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#    "html_attributions" : [],
#    "results" : [],
#    "status" : "REQUEST_DENIED"
# }
#
# {
# ...

# %%
response.json()
# Out:
# {'error_message': 'You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started',
#  'html_attributions': [],
#  'results': [],
#  'status': 'REQUEST_DENIED'}
